# %% [markdown]
# <a href="https://colab.research.google.com/github/amrKidwai/Lending-Club-Risk-Analysis/blob/main/Lending_Club_Risk_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 - Install Libraries

# %%
#pip install pandas numpy matplotlib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #2. Import Data

# %%
import pandas as pd

df = pd.read_csv("loan_data.csv.csv", low_memory=False)

print(df.head())
print(df.shape)
print(df.columns.tolist())

# %% [markdown]
# #3.Identify Important Columns

# %%
important_cols = [
    'loan_amnt',
    'term',
    'int_rate',
    'installment',
    'grade',
    'sub_grade',
    'emp_length',
    'home_ownership',
    'annual_inc',
    'loan_status',
    'purpose',
    'addr_state',
    'dti'
]

df = df[important_cols]

# %% [markdown]
# #4.Create Default Flag

# %%
df['default_flag'] = df['loan_status'].apply(
    lambda x: 1 if x in ['Charged Off', 'Default'] else 0
)

# %% [markdown]
# #5.Check Basic Insights

# %%
print(df['default_flag'].mean()*100)

# %%
print(df.groupby('grade')['default_flag'].mean())

# %%
print(df.groupby('purpose')['loan_amnt'].mean())

# %% [markdown]
# #6.Export Cleaned Data

# %%
df.to_csv("cleaned_loan_data.csv", index=False)
